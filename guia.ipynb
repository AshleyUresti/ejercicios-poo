# %% [markdown]
# # De Java a Python: Guía para ser chipocludos y no morir en el intento.
#
# En Java, estamos acostumbrados a declarar todo de forma muy estricta. Tenemos que definir si algo es público, privado, qué tipo de dato es, y hacer constructores y getters/setters para todo.
#
# Mira cómo se veía nuestra clase `Carro` original en Java:
#
# ```mermaid
# classDiagram
#     class Carro {
#         -String color
#         -int año
#         -String serie
#         +Carro()
#         +Carro(String color, int año, String serie)
#         +getColor() String
#         +setColor(String color) void
#         +getAño() int
#         +setAño(int año) void
#         +getSerie() String
#         +setSerie(String serie) void
#     }

# %% [markdown]
# Ojo aquí: El símbolo - significa que son atributos private (privados) y el + que los métodos son public (públicos).

# %% [markdown]
# <br>
#
# ### 🏆 ¡Etapa 1 Completada: El Molde de Java!
# Ya analizamos la estructura. ¡Sigamos con Python!
#
# <div style="width: 100%; background-color: #2b2b2b; border-radius: 10px; margin-top: 10px; border: 1px solid #444;">
#   <div style="width: 25%; height: 22px; background-color: #ffaa00; border-radius: 10px; text-align: center; color: black; font-weight: bold; font-family: sans-serif; font-size: 14px; line-height: 22px;">
#     25%
#   </div>
# </div>

# %% [markdown]
# ## Etapa 2 -- Creando la clase
#
# Aquí vienen tres diferencias enormes que vas a notar al pasar tu código Java a Python:
#
# 1. En lugar de escribir `private`, en Python le ponemos dos guiones bajos antes del nombre (ejemplo: `__color`). Eso le dice a Python "ey, esto es privado, no lo toques desde afuera".
# 2. **Tipos de datos (Type Hints):** Python adivina los tipos de datos, pero como venimos de Java y nos gusta el orden, usaremos *Type Hints* (`: str`, `: int`) para que quede clarísimo.
# 3. **El truco del Constructor:** En Java hacíamos un constructor vacío `Carro()` y otro con parámetros `Carro(color, año, serie)`. En Python **solo puede haber un constructor** (`__init__`). ¿Cómo lo resolvemos? Dándole valores por defecto a los parámetros.
#
# ¡Ejecuta la siguiente celda para ver la clase en acción!

# %%
class Carro:
    # 1. Nuestro único constructor (__init__)
    # Le ponemos valores por defecto para que funcione como constructor vacío Y con parámetros
    def __init__(self, color: str = "Sin definir", año: int = 0, serie: str = "0000-0000"):
        # 2. Atributos privados (usando los dobles guiones bajos __ )
        self.__color = color
        self.__año = año
        self.__serie = serie

    # 3. GETTERS
    def get_color(self) -> str:
        return self.__color
        
    def get_año(self) -> int:
        return self.__año
        
    def get_serie(self) -> str:
        return self.__serie

    # 4. SETTERS
    def set_color(self, color: str):
        self.__color = color
        
    def set_año(self, año: int):
        self.__año = año
        
    def set_serie(self, serie: str):
        self.__serie = serie

# ==========================================
# CLASE MAIN (Aquí instanciamos los objetos)
# ==========================================

# Carro 1: Usamos el "constructor vacío" (tomará los valores por defecto)
carro_1 = Carro()

# Carro 2: Usamos el constructor con parámetros
carro_2 = Carro("Negro", 2026, "XV-777")

# Imprimimos para comprobar que los getters funcionan
print("CARRO 1 (Constructor vacío):")
print(f"Color: {carro_1.get_color()} | Año: {carro_1.get_año()} | Serie: {carro_1.get_serie()}\n")

print("CARRO 2 (Constructor con parámetros):")
print(f"Color: {carro_2.get_color()} | Año: {carro_2.get_año()} | Serie: {carro_2.get_serie()}")
# Out:
# CARRO 1 (Constructor vacío):
# Color: Sin definir | Año: 0 | Serie: 0000-0000
#
# CARRO 2 (Constructor con parámetros):
# Color: Negro | Año: 2026 | Serie: XV-777

# %% [markdown]
# <br>
#
# ### 🏆 ¡Etapa 2 Completada!
# Ya dominas los constructores y la privacidad en Python.
#
# <div style="width: 100%; background-color: #2b2b2b; border-radius: 10px; margin-top: 10px; border: 1px solid #444;">
#   <div style="width: 50%; height: 22px; background-color: #00cc66; border-radius: 10px; text-align: center; color: black; font-weight: bold; font-family: sans-serif; font-size: 14px; line-height: 22px;">
#     50%
#   </div>
# </div>
